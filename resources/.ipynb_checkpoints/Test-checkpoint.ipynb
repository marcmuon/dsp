# %%
# !pwd
# Out:
# /Users/marcmuon/Dropbox/Projects/metis-prework/dsp/resources

# %%
# !python --version
# Out:
# Python 3.6.6 :: Anaconda custom (64-bit)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,2*np.pi,1000)
y = np.sin(x) + np.cos(x)

# %%
_ = plt.plot(x,y)
